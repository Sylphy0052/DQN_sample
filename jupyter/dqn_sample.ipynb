# %% [markdown]
# # DQNで棒倒しを強化学習する

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym
import warnings
warnings.simplefilter('ignore')
from datetime import datetime

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

# %%
def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    anim.save('movie_cartpole_DQN{}.mp4'.format(datetime.now().strftime('%Y%m%d%H%M%S')))
#     display(display_animation(anim, default_mode='loop'))

# %%
from collections import namedtuple

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0' # 課題名
GAMMA = 0.99 # 時間割引率
MAX_STEPS = 200 # 1試行のstep数
NUM_EPISODES = 500 # 最大試行回数

# %%
class ReplayMemory:
    """
    経験を保存するメモリクラスを定義
    """
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY # メモリ最大の長さ
        self.memory = [] # 経験を保存する
        self.index = 0 # 保存するinndexを示す
        
    def push(self, state, action, state_next, reward):
        """
        transitionをメモリに保存する
        """
        if len(self.memory) < self.capacity:
            # メモリがいっぱいでなければ足す
            self.memory.append(None)

        # 値とフィールド名をペアにして保存する
        self.memory[self.index] = Transition(state, action, state_next, reward)
        # 保存するindexをずらす
        self.index = (self.index + 1) % self.capacity
        
    def sample(self, batch_size):
        """
        バッチサイズ分だけランダムに保存内容を取り出す
        """
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

# %%
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

# %%
BATCH_SIZE = 32
CAPACITY = 10000

# %%
class Brain:
    """
    DQNを実行する。
    Q関数をディープラーニングのネットワークをクラスとして定義する
    """
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions # 行動は2つ(右or左)
        self.memory = ReplayMemory(CAPACITY) # 経験を記憶する
        
        # ニューラルネットワークを定義
        # 4→32→32→2
        self.model = nn.Sequential()
        self.model.add_module('fc1', nn.Linear(num_states, 32))
        self.model.add_module('relu1', nn.ReLU())
        self.model.add_module('fc2', nn.Linear(32, 32))
        self.model.add_module('relu2', nn.ReLU())
        self.model.add_module('fc3', nn.Linear(32, num_actions))
        
        print(self.model) # ネットワークの形を出力
        
        # 最適化手法の設定
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)
        
    def replay(self):
        """
        Experience Replayでネットワークの結合パラメータを学習
        """
        # メモリサイズの確認
        # メモリサイズがミニバッチより小さければ何もしない
        if len(self.memory) < BATCH_SIZE:
            return
        
        # ミニバッチの作成
        # メモリからミニバッチ分のデータを取得する
        transitions = self.memory.sample(BATCH_SIZE)
        # (state, actionn, state_next, reward) x BATCH_SIZEにする
        batch = Transition(*zip(*transitions))
        # 各変数の要素をミニバッチに対応する形に変形する
        # catは結合
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
        
        # 教師信号となるQ(st, at)を求める
        # ネットワークを推論モードに切り替える
        self.model.eval()
        # ネットワークが出力したQ(st, at)を求める
        state_action_values = self.model(state_batch).gather(1, action_batch)
        
        # max{Q(st+1, a)}を求める
        # 終了しておらず、next_stateがあるかをチェックするインデックスマスクを作成
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.next_state)))
        # 全部0にセットする
        next_state_values = torch.zeros(BATCH_SIZE)
        # 次の状態があるindexの最大Q値を求める
        next_state_values[non_final_mask] = self.model(non_final_next_states).max(1)[0].detach()
        
        # 教師となるQ(st, at)をQ学習の式から求める
        expected_state_action_values = reward_batch + GAMMA * next_state_values
        
        # 結合パラメータの更新
        # ネットワークを訓練モードに切り替える
        self.model.train()
        
        # 損失関数の計算
        loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
        
        # 結合パラメータを更新
        # 勾配をリセット
        self.optimizer.zero_grad()
        # バックプロパゲーションを計算
        loss.backward()
        # 結合パラメータを更新
        self.optimizer.step()
        
    def decide_action(self, state, episode):
        """
        現在の状態に応じて行動を決定する
        """
        # ε-greedy法で徐々に最適行動のみを採用する
        epsilon = 0.5 * (1 / (episode + 1))
        
        if epsilon <= np.random.uniform(0, 1):
            # ネットワークを推論モードに切り替える
            self.model.eval()
            with torch.no_grad():
                # ネットワークの最大値のindexを取り出す
                action = self.model(state).max(1)[1].view(1, 1)
        else:
            # 0,1の行動をランダムに返す
            action = torch.LongTensor([[random.randrange(self.num_actions)]])
            
        return action

# %%
class Agent:
    """
    エージェントクラス
    """
    def __init__(self, num_states, num_actions):
        """
        課題の状態と行動の数を設定する
        """
        # エージェントが行動を決定するための頭脳を生成
        self.brain = Brain(num_states, num_actions)
        
    def update_q_function(self):
        """
        Q関数の更新
        """
        self.brain.replay()
        
    def get_action(self, state, episode):
        """
        行動の決定
        """
        action = self.brain.decide_action(state, episode)
        return action
    
    def memorize(self, state, action, state_next, reward):
        """
        memoryオブジェクトにstatte,action,state_next,rewardを保存する
        """
        self.brain.memory.push(state, action, state_next, reward)

# %%
class Environment:
    """
    環境クラス
    """
    def __init__(self):
        # 実行する課題を設定
        self.env = gym.make(ENV)
        # 課題の状態数(4)を取得
        num_states = self.env.observation_space.shape[0]
        # 行動数(2)を取得
        num_actions = self.env.action_space.n
        # 環境内で行動するAgentを生成
        self.agent = Agent(num_states, num_actions)
        
    def run(self):
        """
        実行
        """
        # 10試行分の立ち続けたstep数を格納する
        episode_10_list = np.zeros(10)
        # 195step以上立ち続けた試行数
        complete_episodes = 0
        # 最後の試行フラグ
        episode_final = False
        # 画像を格納する
        frames = []
        
        # 最大試行数分繰り返す
        for episode in range(NUM_EPISODES):
            # 環境の初期化
            observation = self.env.reset()
            
            # 観測を状態sとして使用
            state = observation
            state = torch.from_numpy(state).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)
            
            # 1エピソードのループ
            for step in range(MAX_STEPS):
                # 最終試行では画像を保存する
                if episode_final:
                    frames.append(self.env.render(mode='rgb_array'))
                # 行動を求める
                action = self.agent.get_action(state, episode)
                
                # atの実行によりst+1とdoneフラグを求める
                observation_next, _, done, _ = self.env.step(action.item())
                
                # 報酬を与える。episodeの終了評価とstate_nextの設定
                # ステップ数が200を超える、または一定角度以上傾くとdone=Falseとなる
                if done:
                    state_next = None
                    
                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))
                    
                    # 失敗ならば報酬-1を与える
                    if step < 195:
                        reward = torch.FloatTensor([-1.0])
                        complete_episodes = 0
                    else: # 成功ならば報酬1を与える
                        reward = torch.FloatTensor([1.0])
                        complete_episodes = complete_episodes + 1
                else:
                    # 普段は報酬0
                    reward = torch.FloatTensor([0.0])
                    # 観測を状態とする
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)
                    
                # メモリに経験を追加
                self.agent.memorize(state, action, state_next, reward)
                # Q関数の更新
                self.agent.update_q_function()
                # 観測の更新
                state = state_next

                # 終了時の処理
                if done:
                    print('{} Episode: Finished after {} steps: 10試行の平均step数: {:.1f}'.format(episode, step + 1, episode_10_list.mean()))
                    break
                    
            if episode_final is True:
                display_frames_as_gif(frames)
                break

            if complete_episodes >= 10:
                print('10回連続成功')
                episode_final = True

# %%
for i in range(20):
    cartpole_env = Environment()
    cartpole_env.run()
# Out:
# Sequential(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 16 steps: 10試行の平均step数: 1.6
# 1 Episode: Finished after 9 steps: 10試行の平均step数: 2.5
# 2 Episode: Finished after 8 steps: 10試行の平均step数: 3.3
# 3 Episode: Finished after 10 steps: 10試行の平均step数: 4.3
# 4 Episode: Finished after 10 steps: 10試行の平均step数: 5.3
# 5 Episode: Finished after 11 steps: 10試行の平均step数: 6.4
# 6 Episode: Finished after 8 steps: 10試行の平均step数: 7.2
# 7 Episode: Finished after 10 steps: 10試行の平均step数: 8.2
# 8 Episode: Finished after 9 steps: 10試行の平均step数: 9.1
# 9 Episode: Finished after 12 steps: 10試行の平均step数: 10.3
# 10 Episode: Finished after 10 steps: 10試行の平均step数: 9.7
# 11 Episode: Finished after 9 steps: 10試行の平均step数: 9.7
# 12 Episode: Finished after 9 steps: 10試行の平均step数: 9.8
# 13 Episode: Finished after 11 steps: 10試行の平均step数: 9.9
# 14 Episode: Finished after 11 steps: 10試行の平均step数: 10.0
# 15 Episode: Finished after 11 steps: 10試行の平均step数: 10.0
# 16 Episode: Finished after 12 steps: 10試行の平均step数: 10.4
# 17 Episode: Finished after 11 steps: 10試行の平均step数: 10.5
# 18 Episode: Finished after 10 steps: 10試行の平均step数: 10.6
# 19 Episode: Finished after 10 steps: 10試行の平均step数: 10.4
# 20 Episode: Finished after 11 steps: 10試行の平均step数: 10.5
# 21 Episode: Finished after 11 steps: 10試行の平均step数: 10.7
# 22 Episode: Finished after 11 steps: 10試行の平均step数: 10.9
# 23 Episode: Finished after 10 steps: 10試行の平均step数: 10.8
# 24 Episode: Finished after 13 steps: 10試行の平均step数: 11.0
# 25 Episode: Finished after 9 steps: 10試行の平均step数: 10.8
# 26 Episode: Finished after 10 steps: 10試行の平均step数: 10.6
# 27 Episode: Finished after 10 steps: 10試行の平均step数: 10.5
# 28 Episode: Finished after 14 steps: 10試行の平均step数: 10.9
# 29 Episode: Finished after 13 steps: 10試行の平均step数: 11.2
# 30 Episode: Finished after 14 steps: 10試行の平均step数: 11.5
# 31 Episode: Finished after 11 steps: 10試行の平均step数: 11.5
# 32 Episode: Finished after 12 steps: 10試行の平均step数: 11.6
# 33 Episode: Finished after 12 steps: 10試行の平均step数: 11.8
# 34 Episode: Finished after 10 steps: 10試行の平均step数: 11.5
# 35 Episode: Finished after 16 steps: 10試行の平均step数: 12.2
# 36 Episode: Finished after 15 steps: 10試行の平均step数: 12.7
# 37 Episode: Finished after 11 steps: 10試行の平均step数: 12.8
# 38 Episode: Finished after 14 steps: 10試行の平均step数: 12.8
# 39 Episode: Finished after 14 steps: 10試行の平均step数: 12.9
# 40 Episode: Finished after 16 steps: 10試行の平均step数: 13.1
# 41 Episode: Finished after 13 steps: 10試行の平均step数: 13.3
# 42 Episode: Finished after 20 steps: 10試行の平均step数: 14.1
# 43 Episode: Finished after 8 steps: 10試行の平均step数: 13.7
# 44 Episode: Finished after 9 steps: 10試行の平均step数: 13.6
# 45 Episode: Finished after 9 steps: 10試行の平均step数: 12.9
# 46 Episode: Finished after 9 steps: 10試行の平均step数: 12.3
# 47 Episode: Finished after 8 steps: 10試行の平均step数: 12.0
# 48 Episode: Finished after 9 steps: 10試行の平均step数: 11.5
# 49 Episode: Finished after 9 steps: 10試行の平均step数: 11.0
# 50 Episode: Finished after 10 steps: 10試行の平均step数: 10.4
# 51 Episode: Finished after 10 steps: 10試行の平均step数: 10.1
# 52 Episode: Finished after 9 steps: 10試行の平均step数: 9.0
# 53 Episode: Finished after 49 steps: 10試行の平均step数: 13.1
# 54 Episode: Finished after 25 steps: 10試行の平均step数: 14.7
# 55 Episode: Finished after 9 steps: 10試行の平均step数: 14.7
# 56 Episode: Finished after 9 steps: 10試行の平均step数: 14.7
# 57 Episode: Finished after 41 steps: 10試行の平均step数: 18.0
# 58 Episode: Finished after 29 steps: 10試行の平均step数: 20.0
# 59 Episode: Finished after 34 steps: 10試行の平均step数: 22.5
# 60 Episode: Finished after 45 steps: 10試行の平均step数: 26.0
# 61 Episode: Finished after 28 steps: 10試行の平均step数: 27.8
# 62 Episode: Finished after 34 steps: 10試行の平均step数: 30.3
# 63 Episode: Finished after 50 steps: 10試行の平均step数: 30.4
# 64 Episode: Finished after 39 steps: 10試行の平均step数: 31.8
# 65 Episode: Finished after 45 steps: 10試行の平均step数: 35.4
# 66 Episode: Finished after 43 steps: 10試行の平均step数: 38.8
# 67 Episode: Finished after 36 steps: 10試行の平均step数: 38.3
# 68 Episode: Finished after 73 steps: 10試行の平均step数: 42.7
# 69 Episode: Finished after 36 steps: 10試行の平均step数: 42.9
# 70 Episode: Finished after 46 steps: 10試行の平均step数: 43.0
# 71 Episode: Finished after 56 steps: 10試行の平均step数: 45.8
# 72 Episode: Finished after 34 steps: 10試行の平均step数: 45.8
# 73 Episode: Finished after 28 steps: 10試行の平均step数: 43.6
# 74 Episode: Finished after 38 steps: 10試行の平均step数: 43.5
# 75 Episode: Finished after 34 steps: 10試行の平均step数: 42.4
# 76 Episode: Finished after 39 steps: 10試行の平均step数: 42.0
# 77 Episode: Finished after 43 steps: 10試行の平均step数: 42.7
# 78 Episode: Finished after 65 steps: 10試行の平均step数: 41.9
# 79 Episode: Finished after 68 steps: 10試行の平均step数: 45.1
# 80 Episode: Finished after 39 steps: 10試行の平均step数: 44.4
# 81 Episode: Finished after 45 steps: 10試行の平均step数: 43.3
# 82 Episode: Finished after 75 steps: 10試行の平均step数: 47.4
# 83 Episode: Finished after 43 steps: 10試行の平均step数: 48.9
# 84 Episode: Finished after 58 steps: 10試行の平均step数: 50.9
# 85 Episode: Finished after 81 steps: 10試行の平均step数: 55.6
# 86 Episode: Finished after 62 steps: 10試行の平均step数: 57.9
# 87 Episode: Finished after 36 steps: 10試行の平均step数: 57.2
# 88 Episode: Finished after 55 steps: 10試行の平均step数: 56.2
# 89 Episode: Finished after 43 steps: 10試行の平均step数: 53.7
# 90 Episode: Finished after 46 steps: 10試行の平均step数: 54.4
# 91 Episode: Finished after 106 steps: 10試行の平均step数: 60.5
# 92 Episode: Finished after 36 steps: 10試行の平均step数: 56.6
# 93 Episode: Finished after 63 steps: 10試行の平均step数: 58.6
# 94 Episode: Finished after 49 steps: 10試行の平均step数: 57.7
# 95 Episode: Finished after 58 steps: 10試行の平均step数: 55.4
# 96 Episode: Finished after 75 steps: 10試行の平均step数: 56.7
# 97 Episode: Finished after 88 steps: 10試行の平均step数: 61.9
# 98 Episode: Finished after 200 steps: 10試行の平均step数: 76.4
# 99 Episode: Finished after 166 steps: 10試行の平均step数: 88.7
# 100 Episode: Finished after 85 steps: 10試行の平均step数: 92.6
# 101 Episode: Finished after 71 steps: 10試行の平均step数: 89.1
# 102 Episode: Finished after 179 steps: 10試行の平均step数: 103.4
# 103 Episode: Finished after 200 steps: 10試行の平均step数: 117.1
# 104 Episode: Finished after 104 steps: 10試行の平均step数: 122.6
# 105 Episode: Finished after 86 steps: 10試行の平均step数: 125.4
# 106 Episode: Finished after 173 steps: 10試行の平均step数: 135.2
# 107 Episode: Finished after 112 steps: 10試行の平均step数: 137.6
# 108 Episode: Finished after 110 steps: 10試行の平均step数: 128.6
# 109 Episode: Finished after 150 steps: 10試行の平均step数: 127.0
# 110 Episode: Finished after 200 steps: 10試行の平均step数: 138.5
# 111 Episode: Finished after 170 steps: 10試行の平均step数: 148.4
# 112 Episode: Finished after 113 steps: 10試行の平均step数: 141.8
# 113 Episode: Finished after 146 steps: 10試行の平均step数: 136.4
# 114 Episode: Finished after 53 steps: 10試行の平均step数: 131.3
# 115 Episode: Finished after 200 steps: 10試行の平均step数: 142.7
# 116 Episode: Finished after 183 steps: 10試行の平均step数: 143.7
# 117 Episode: Finished after 200 steps: 10試行の平均step数: 152.5
# 118 Episode: Finished after 70 steps: 10試行の平均step数: 148.5
# 119 Episode: Finished after 146 steps: 10試行の平均step数: 148.1
# 120 Episode: Finished after 200 steps: 10試行の平均step数: 148.1
# 121 Episode: Finished after 200 steps: 10試行の平均step数: 151.1
# 122 Episode: Finished after 200 steps: 10試行の平均step数: 159.8
# 123 Episode: Finished after 200 steps: 10試行の平均step数: 165.2
# 124 Episode: Finished after 200 steps: 10試行の平均step数: 179.9
# 125 Episode: Finished after 200 steps: 10試行の平均step数: 179.9
# 126 Episode: Finished after 152 steps: 10試行の平均step数: 176.8
# 127 Episode: Finished after 137 steps: 10試行の平均step数: 170.5
# 128 Episode: Finished after 200 steps: 10試行の平均step数: 183.5
# 129 Episode: Finished after 200 steps: 10試行の平均step数: 188.9
# 130 Episode: Finished after 200 steps: 10試行の平均step数: 188.9
# 131 Episode: Finished after 200 steps: 10試行の平均step数: 188.9
# 132 Episode: Finished after 200 steps: 10試行の平均step数: 188.9
# 133 Episode: Finished after 200 steps: 10試行の平均step数: 188.9
# 134 Episode: Finished after 200 steps: 10試行の平均step数: 188.9
# 135 Episode: Finished after 200 steps: 10試行の平均step数: 188.9
# 136 Episode: Finished after 200 steps: 10試行の平均step数: 193.7
# 137 Episode: Finished after 200 steps: 10試行の平均step数: 200.0
# 10回連続成功
# 138 Episode: Finished after 200 steps: 10試行の平均step数: 200.0
